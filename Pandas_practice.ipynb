# %% [markdown]
# ## SERIES

# %%
import pandas as pd
ice_cream =["choc",'van','straw','rum-raisin']
pd.Series(ice_cream)
# Out:
# 0          choc
# 1           van
# 2         straw
# 3    rum-raisin
# dtype: object

# %%
l= [4,5,8,7,4,9]
pd.Series(l)
# Out:
# 0    4
# 1    5
# 2    8
# 3    7
# 4    4
# 5    9
# dtype: int64

# %%
reg=[True,False,False,False,True]
pd.Series(reg)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
# Non numeric indexes
# can have repeating indexes


web={'A':"is an animal",
     'Banana':'is a sooper fruit',
    'Cyna':'someone who i dont knw'}
pd.Series(web)
# Out:
# A                   is an animal
# Banana         is a sooper fruit
# Cyna      someone who i dont knw
# dtype: object

# %% [markdown]
# ### ATTRIBUTES
# #### values,attributes...

# %%
about_me =['smart','ciye','humble','dog']
s=pd.Series(about_me)
s
# Out:
# 0     smart
# 1      ciye
# 2    humble
# 3       dog
# dtype: object

# %%
#returns values
s.values
# Out:
# array(['smart', 'ciye', 'humble', 'dog'], dtype=object)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s.dtype
# Out:
# dtype('O')

# %% [markdown]
# ### METHODS INTRO
# #### (It does something to the object...like adding values,deleting values etc..)

# %%
prices=[2.99,7.09,77.88]
s=pd.Series(prices)
s
# Out:
# 0     2.99
# 1     7.09
# 2    77.88
# dtype: float64

# %%
s.sum()
# Out:
# 87.96

# %%
s.product()
# Out:
# 1650.985908

# %%
s.mean()
# Out:
# 29.319999999999997

# %% [markdown]
# ### Parameters and Arguments
# #### (parameter is the name of the option and argument is the option that we choose)

# %%
'''
pd.Series(
    data=None,
    index=None,
    dtype=None,
    name=None,
    copy=False,
    fastpath=False,
)
'''


fruits =['app','bana','cal','dogfruit']
weekdays = ['Monday','Tue','Wed','Thiur']
pd.Series(fruits,weekdays)
pd.Series(data=fruits,index=weekdays)
pd.Series(fruits,inex=weekdays)
# Out:
# Monday         app
# Tue           bana
# Wed            cal
# Thiur     dogfruit
# dtype: object

# %%
fruits =['app','bana','cal','dogfruit','watermelon']
weekdays = ['Monday','Tue','Wed','Thiur','Monday']
pd.Series(fruits,index=weekdays)
# Out:
# Monday           app
# Tue             bana
# Wed              cal
# Thiur       dogfruit
# Monday    watermelon
# dtype: object

# %%
pokemon=pd.read_csv('pokemon.csv',usecols=['Name'],squeeze=True)
pokemon.head()
#use_cols= colums we want to use
#squeeze to convert df into Series
# len(Series_obj)==> gives no of rows
#looking into pandaws built in python functions usage
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
type(pokemon)
# Out:
# pandas.core.series.Series

# %%
sorted(pokemon)
# Out:
# ['Abomasnow',
#  'AbomasnowMega Abomasnow',
#  'Abra',
#  'Absol',
#  'AbsolMega Absol',
#  'Accelgor',
#  'AegislashBlade Forme',
#  'AegislashShield Forme',
#  'Aerodactyl',
#  'AerodactylMega Aerodactyl',
#  'Aggron',
#  'AggronMega Aggron',
#  'Aipom',
#  'Alakazam',
#  'AlakazamMega Alakazam',
#  'Alomomola',
#  'Altaria',
#  'AltariaMega Altaria',
#  'Amaura',
#  'Ambipom',
#  'Amoonguss',
#  'Ampharos',
#  'AmpharosMega Ampharos',
#  'Anorith',
#  'Arbok',
#  'Arcanine',
#  'Arceus',
#  'Archen',
#  'Archeops',
#  'Ariados',
#  'Armaldo',
#  'Aromatisse',
#  'Aron',
#  'Articuno',
#  'Audino',
#  'AudinoMega Audino',
#  'Aurorus',
#  'Avalugg',
#  'Axew',
#  'Azelf',
#  'Azumarill',
#  'Azurill',
#  'Bagon',
#  'Baltoy',
#  'Banette',
#  'BanetteMega Banette',
#  'Barbaracle',
#  'Barboach',
#  'Basculin',
#  'Bastiodon',
#  'Bayleef',
#  'Beartic',
#  'Beautifly',
#  'Beedrill',
#  'BeedrillMega Beedrill',
#  'Beheeyem',
#  'Beldum',
#  'Bellossom',
#  'Bellsprout',
# ...

# %%
dict(pokemon)
# Out:
# {0: 'Bulbasaur',
#  1: 'Ivysaur',
#  2: 'Venusaur',
#  3: 'VenusaurMega Venusaur',
#  4: 'Charmander',
#  5: 'Charmeleon',
#  6: 'Charizard',
#  7: 'CharizardMega Charizard X',
#  8: 'CharizardMega Charizard Y',
#  9: 'Squirtle',
#  10: 'Wartortle',
#  11: 'Blastoise',
#  12: 'BlastoiseMega Blastoise',
#  13: 'Caterpie',
#  14: 'Metapod',
#  15: 'Butterfree',
#  16: 'Weedle',
#  17: 'Kakuna',
#  18: 'Beedrill',
#  19: 'BeedrillMega Beedrill',
#  20: 'Pidgey',
#  21: 'Pidgeotto',
#  22: 'Pidgeot',
#  23: 'PidgeotMega Pidgeot',
#  24: 'Rattata',
#  25: 'Raticate',
#  26: 'Spearow',
#  27: 'Fearow',
#  28: 'Ekans',
#  29: 'Arbok',
#  30: 'Pikachu',
#  31: 'Raichu',
#  32: 'Sandshrew',
#  33: 'Sandslash',
#  34: 'Nidoran♀',
#  35: 'Nidorina',
#  36: 'Nidoqueen',
#  37: 'Nidoran♂',
#  38: 'Nidorino',
#  39: 'Nidoking',
#  40: 'Clefairy',
#  41: 'Clefable',
#  42: 'Vulpix',
#  43: 'Ninetales',
#  44: 'Jigglypuff',
#  45: 'Wigglytuff',
#  46: 'Zubat',
#  47: 'Golbat',
#  48: 'Oddish',
# ...

# %%
max(pokemon)
min(pokemon)
# Out:
# 'Abomasnow'

# %%
pokemon.dtype
pokemon.is_unique
# Out:
# True

# %%
pokemon.ndim #series is always a one dimentional data
# Out:
# 1

# %%
pokemon.shape
pokemon.size
pokemon.name="pocket monseter"
pokemon.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: pocket monseter, dtype: object

# %%
pokemon.sort_values().head()
# Out:
# 510                  Abomasnow
# 511    AbomasnowMega Abomasnow
# 68                        Abra
# 392                      Absol
# 393            AbsolMega Absol
# Name: pocket monseter, dtype: object

# %%
pokemon.sort_values(ascending=False).head() # usual df is not modified ,new series is returned #does not overwrite original;
# Out:
# 794    Zygarde50% Forme
# 695            Zweilous
# 46                Zubat
# 631               Zorua
# 632             Zoroark
# Name: pocket monseter, dtype: object

# %%
# INPLACE PARAMETER MODIFIES THYE GIVEN SERIES IN PLACE
pokemon=pokemon.sort_values()
pokemon
#else use inplace parameter i.e inplace = True
# Out:
# 510                  Abomasnow
# 511    AbomasnowMega Abomasnow
# 68                        Abra
# 392                      Absol
# 393            AbsolMega Absol
# Name: pocket monseter, dtype: object

# %%
pokemon = pd.read_csv('pokemon.csv',usecols=['Name'],squeeze=True)
pokemon.sort_values(ascending=True,inplace=True)
pokemon
# Out:
# 510                  Abomasnow
# 511    AbomasnowMega Abomasnow
# 68                        Abra
# 392                      Absol
# 393            AbsolMega Absol
#                 ...
# 632                    Zoroark
# 631                      Zorua
# 46                       Zubat
# 695                   Zweilous
# 794           Zygarde50% Forme
# Name: Name, Length: 800, dtype: object

# %%
pokemon.sort_index(ascending = True,inplace=True)
pokemon.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
#in KEYWORD
100 in pokemon.index
# Out:
# True

# %%
pokemon = pd.read_csv('pokemon.csv',usecols=['Name'],squeeze=True)
pokemon.head(3)
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Name, dtype: object

# %%
pokemon[500]
# Out:
# <bound method Series.keys of 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object>

# %%
pokemon[[100,200,400]]
# Out:
# 100      Haunter
# 200    Sudowoodo
# 400      Walrein
# Name: Name, dtype: object

# %%
pokemon=pokemon = pd.read_csv('pokemon.csv',usecols=['Name','Type 1'],index_col="Name",squeeze = True)
pokemon.head()
pokemon[[0,100,134]]
# Out:
# Name
# Bulbasaur        Grass
# Haunter          Ghost
# Electabuzz    Electric
# Name: Type 1, dtype: object

# %%
pokemon["Bulbasaur"]
pokemon[["Ditto","mionnie"]]
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py:1152: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]
# Name
# Ditto      Normal
# mionnie       NaN
# Name: Type 1, dtype: object

# %%
pokemon["Bulbasaur":"Pikachu"]
# Out:
# Name
# Bulbasaur                       Grass
# Ivysaur                         Grass
# Venusaur                        Grass
# VenusaurMega Venusaur           Grass
# Charmander                       Fire
# Charmeleon                       Fire
# Charizard                        Fire
# CharizardMega Charizard X        Fire
# CharizardMega Charizard Y        Fire
# Squirtle                        Water
# Wartortle                       Water
# Blastoise                       Water
# BlastoiseMega Blastoise         Water
# Caterpie                          Bug
# Metapod                           Bug
# Butterfree                        Bug
# Weedle                            Bug
# Kakuna                            Bug
# Beedrill                          Bug
# BeedrillMega Beedrill             Bug
# Pidgey                         Normal
# Pidgeotto                      Normal
# Pidgeot                        Normal
# PidgeotMega Pidgeot            Normal
# ...

# %%
#GET METHOD IN SERIES

# %%
pokemon = pd.read_csv('pokemon.csv',usecols=['Name','Type 1'],index_col="Name",squeeze = True)
pokemon.sort_index(inplace=True)
pokemon.head(3)
# Out:
# Name
# Abomasnow                    Grass
# AbomasnowMega Abomasnow      Grass
# Abra                       Psychic
# Name: Type 1, dtype: object

# %%
#instead of sq brackets we csan use get() method
pokemon.get("Pikachu")
# Out:
# 'Electric'

# %%
pokemon.get(key=["pikachu","Bulbasaur"],default="This is not a pokemon") #ignores default parameter when dealing wioth lisyt param in key
# Out:
# Name
# pikachu        NaN
# Bulbasaur    Grass
# Name: Type 1, dtype: object

# %% [markdown]
# #### Math Methods on series Objects

# %%
# df.count() count wont include missing values (number opf values)
# len(df)
# df.sum()
#df.std() standar deviation
#df.min()
#df.max()
#def.median()
#df.mode()
#df.describe() gives statistical summary
#df.idxmax() (returns index which has maximum value)
#df.idxmin() (returns index with smallestr value)

# %%
pokemon = pd.read_csv('pokemon.csv',usecols=['Name','Type 1'],index_col="Name",squeeze = True)
pokemon.head()
# Out:
# Name
# Bulbasaur                Grass
# Ivysaur                  Grass
# Venusaur                 Grass
# VenusaurMega Venusaur    Grass
# Charmander                Fire
# Name: Type 1, dtype: object

# %%
# count = counts how many times a value occurs in a series
pokemon.value_counts() #this is the series
pokemon.value_counts().sum()
# pokemon.count()
pokemon.value_counts(ascending=True)
# Out:
# Flying        4
# Fairy        17
# Ice          24
# Steel        27
# Fighting     27
# Poison       28
# Dark         31
# Dragon       32
# Ground       32
# Ghost        32
# Rock         44
# Electric     44
# Fire         52
# Psychic      57
# Bug          69
# Grass        70
# Normal       98
# Water       112
# Name: Type 1, dtype: int64

# %%
# apply() method uses a function for each record in the series
# defining a function
# def class_per(number):
#     if number < 300:
#         return 'OK'
#     elif number>300 and number<600:
#         return 'Satisfcatory'
#     else:
#         return "Incredible"
# numeric_df.apply(class_per)
# df


# an alsop use anonymous fucntion
# example:
#     df.apply(lambda stock_price:stock_price+1)

# %%
c
pok_names.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
pok_types = pd.read_csv("pokemon.csv",usecols=["Name","Type 1"],index_col="Name",squeeze = True)
pok_types.head()
# Out:
# Name
# Bulbasaur                Grass
# Ivysaur                  Grass
# Venusaur                 Grass
# VenusaurMega Venusaur    Grass
# Charmander                Fire
# Name: Type 1, dtype: object

# %%
pok_names.map(pok_types)  #returns series

# passing python dict
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Name, Length: 800, dtype: object

# %%
pok_types = pd.read_csv("pokemon.csv",usecols=["Name","Type 1"],index_col="Name",squeeze = True)
pok_types = pd.read_csv("pokemon.csv",usecols=["Name","Type 1"],index_col="Name",squeeze = True).to_dict()
pok_names.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
pok_names.map(pok_types) #will look into the keys of the pokemon_type dictionary
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# # INTRO TO DATAFRAMES

# %%
import pandas as pd
nba = pd.read_csv("pandas/nba.csv")
nba.head()
nba.tail()
nba.index
nba.values
nba.shape
nba.columns
nba.dtypes
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
# exclusive df methods
nba.info() #info qabout df
nba.get_dtype_counts() #shows m=how may columns have a particular datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: `get_dtype_counts` has been deprecated and will be removed in a future version. For DataFrames use `.dtypes.value_counts()
#   This is separate from the ipykernel package so we can avoid doing imports until
# float64    4
# object     5
# dtype: int64

# %% [markdown]
# ### differences between shared methods (series vs data frame)

# %%
rev = pd.read_csv("pandas/revenue.csv",index_col ='Date')
rev.head()
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933
# 1/4/16       730          904    885
# 1/5/16       114           71    253

# %%
s =pd.Series([1,2,3,4])
s.sum()
# Out:
# 10

# %%
rev.sum()
# returns series with sum of all column values
# for sum by date ( we can use axis)
rev.sum(axis=0) # for columns
rev.sum(axis=1) # can also use axis ="columns " moves across columns and sumns up
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
nba = pd.read_csv("pandas/nba.csv")
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.Name
#whenwver we extract a single col;umn pandas returns a series
nba.Number
nba.Salary
#Output = None

# to extract column which have sapaces in name can use brackets
nba["Number"]
type(nba["Name"])
nba["Name"].head()  #method/attribute chaining
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %%
# rtuerning two or more columns from a df
#give a list of columns that u want to extract
nba[["Name","Team"]].head(4)
nba[['Number','College']]
# Out:
#      Number            College
# 0       0.0              Texas
# 1      99.0          Marquette
# 2      30.0  Boston University
# 3      28.0      Georgia State
# 4       8.0                NaN
# ..      ...                ...
# 453     8.0             Butler
# 454    25.0                NaN
# 455    21.0                NaN
# 456    24.0             Kansas
# 457     NaN                NaN
#
# [458 rows x 2 columns]

# %%
#create a list that has columns
l = ["Salary","Team","Name"]
nba[l].head() 

# Adding new columns to the existing df
nba["Sport"] = 'tennis'
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary   Sport
# 0              Texas  7730337.0  tennis
# 1          Marquette  6796117.0  tennis
# 2  Boston University        NaN  tennis
# 3      Georgia State  1148640.0  tennis
# 4                NaN  5000000.0  tennis

# %%
nba = pd.read_csv("pandas/nba.csv")
nba.insert(3,column = "Sport",value ="BB")
nba.head()
nba.insert(7,column ="Message",value="Hello_all")
nba.head()
# Out:
#             Name            Team  Number Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0    BB       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0    BB       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0    BB       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0    BB       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0    BB       PF  29.0   6-10
#
#      Message  Weight            College     Salary
# 0  Hello_all   180.0              Texas  7730337.0
# 1  Hello_all   235.0          Marquette  6796117.0
# 2  Hello_all   205.0  Boston University        NaN
# 3  Hello_all   185.0      Georgia State  1148640.0
# 4  Hello_all   231.0                NaN  5000000.0

# %%
## Broadcasting operations
nba['Age'].add(5)
nba['Age']+5 # also works
nba['Salary'].sub(5000000)
nba["Weightin kg"]=nba["Weight"].mul(0.453592) #nba["Weight"]*0.453592
nba.head()
#nba["Salary"].div(100000) else use '/'
# Out:
#             Name            Team  Number Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0    BB       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0    BB       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0    BB       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0    BB       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0    BB       PF  29.0   6-10
#
#      Message  Weight            College     Salary  Weightin kg
# 0  Hello_all   180.0              Texas  7730337.0    81.646560
# 1  Hello_all   235.0          Marquette  6796117.0   106.594120
# 2  Hello_all   205.0  Boston University        NaN    92.986360
# 3  Hello_all   185.0      Georgia State  1148640.0    83.914520
# 4  Hello_all   231.0                NaN  5000000.0   104.779752

# %% [markdown]
# ## A review of value_counts() method

# %%
nba = pd.read_csv("pandas/nba.csv")
nba["Team"].value_counts()
nba['Position'].value_counts()
nba['Weight'].value_counts()
nba['Salary'].value_counts()

# this method only works on a series
# Out:
# 947276.0     31
# 845059.0     18
# 525093.0     13
# 981348.0      6
# 1100602.0     5
#              ..
# 1242720.0     1
# 2489530.0     1
# 5103120.0     1
# 9463484.0     1
# 700902.0      1
# Name: Salary, Length: 309, dtype: int64

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.dropna(how="all",inplace =True) # has an inplace parameter
nba.tail()
nba.dropna()
#removes all the columns which have null values
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
nba.dropna(subset=["Salary"]) # drops only the rows which have salary column null
nba.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
# fillna() #inptalace param abvailabel use shift+tab
nba = pd.read_csv("pandas/nba.csv").dropna(how="all")
nba.head()
nba.fillna(0) #all Nan will be replaced by 0
nba["Salary"].fillna(0,inplace=True)
nba['College'].fillna("None",inplace=True)
nba.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         0.0
# 3      Georgia State   1148640.0
# ...

# %%
nba.dtypes
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 35.7+ KB

# %%
nba["Salary"]=nba["Salary"].astype("int")
nba.dtypes
nba["Number"]=nba["Number"].astype(int)
nba["Age"]=nba["Age"].astype(int)
nba.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height       object
# Weight      float64
# College      object
# Salary        int64
# dtype: object

# %%
nba["Position"].nunique()   #number of unique values 
nba["Position"]=nba["Position"].astype("category")
nba.info()
nba["Team"]=nba["Team"].astype("category")
nba.head()
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null int64
# Position    457 non-null category
# Age         457 non-null int64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null int64
# dtypes: category(1), float64(1), int64(3), object(4)
# memory usage: 32.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null category
# Number      457 non-null int64
# Position    457 non-null category
# Age         457 non-null int64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null int64
# dtypes: category(2), float64(1), int64(3), object(3)
# memory usage: 31.1+ KB

# %% [markdown]
# ## sort_values()

# %%
nba.sort_values("Name",ascending=False)
nba.sort_values("Age")
nba.sort_values("Salary")
# Out:
#                 Name                 Team  Number Position  Age Height  \
# 397     Axel Toupane       Denver Nuggets       6       SG   23    6-7
# 350    Briante Weber           Miami Heat      12       PG   23    6-2
# 2       John Holland       Boston Celtics      30       SG   27    6-5
# 171    Dahntay Jones  Cleveland Cavaliers      30       SG   35    6-6
# 270   Xavier Munford    Memphis Grizzlies      14       PG   24    6-3
# ..               ...                  ...     ...      ...  ...    ...
# 339       Chris Bosh           Miami Heat       1       PF   32   6-11
# 251    Dwight Howard      Houston Rockets      12        C   30   6-11
# 33   Carmelo Anthony      New York Knicks       7       SF   32    6-8
# 169     LeBron James  Cleveland Cavaliers      23       SF   31    6-8
# 109      Kobe Bryant   Los Angeles Lakers      24       SF   37    6-6
#
#      Weight                College    Salary
# 397   210.0                   None         0
# ...

# %%
#sorting using mul;tiple columns
nba.sort_values(["Number","Salary","Name"],inplace=True)

# %%
# Sorting df using sort_index()
nba.sort_index(ascending=False)
nba.head()
# Out:
#                  Name                  Team  Number Position  Age Height  \
# 291   Orlando Johnson  New Orleans Pelicans       0       SG   27    6-5
# 248  Andrew Goudelock       Houston Rockets       0       PG   27    6-3
# 347   Josh Richardson            Miami Heat       0       SG   22    6-6
# 266    JaMychal Green     Memphis Grizzlies       0       PF   25    6-9
# 47      Isaiah Canaan    Philadelphia 76ers       0       PG   25    6-0
#
#      Weight           College  Salary
# 291   220.0  UC Santa Barbara   55722
# 248   200.0        Charleston  200600
# 347   200.0         Tennessee  525093
# 266   227.0           Alabama  845059
# 47    201.0      Murray State  947276

# %%
nba = pd.read_csv("pandas/nba.csv").dropna(how="all")
nba["Salary"]=nba["Salary"].fillna(0).astype(int)
nba["Salary_rank"]=nba["Salary"].rank(ascending =False).astype(int)
nba.head()
nba.sort_values("Salary",ascending=False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 353    Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 264    Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 273   Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
#
#      Weight       College    Salary  Salary_rank
# ...

# %%
import pandas as pd
df=pd.read_csv("pandas/employees.csv")
df.head()
df["Start Date"]=pd.to_datetime(df["Start Date"])
df["Last Login Time"]= pd.to_datetime(df["Last Login Time"])
df["Senior Management"]=df["Senior Management"].astype(bool)
df["Senior Management"]=df["Senior Management"].astype(bool)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 55.8+ KB

# %%
# can convert a gender column to categoty rather than string
# date are also in string format
#convertinhg start date and times to todatetime

# %%
df["Start Date"]=pd.to_datetime(df["Start Date"])
df["Last Login Time"]= pd.to_datetime(df["Last Login Time"])
df["Last Login Time"].head()
# Out:
# 0   2019-10-15 12:42:00
# 1   2019-10-15 06:53:00
# 2   2019-10-15 11:17:00
# 3   2019-10-15 13:00:00
# 4   2019-10-15 16:47:00
# Name: Last Login Time, dtype: datetime64[ns]

# %%
df["Senior Management"]=df["Senior Management"].astype(bool)

# %%
df["Senior Management"]=df["Senior Management"].astype(bool)
df.info()
df["Team"].nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 55.8+ KB
# 10

# %%
# can also use parse dates in read_csv method

# %% [markdown]
# ### FILTERING OUR DATABASE

# %%
df=pd.read_csv("pandas/employees.csv")
df["Start Date"]=pd.to_datetime(df["Start Date"])
df["Last Login Time"]= pd.to_datetime(df["Last Login Time"])
df["Senior Management"]=df["Senior Management"].astype(bool)
df["Senior Management"]=df["Senior Management"].astype(bool)
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-10-15 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-10-15 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-10-15 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2019-10-15 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2019-10-15 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df["Gender"]=="Male"
# returns a series of true and false
df[df["Gender"]=="Male"] #extracts only a rows which have true returns a df with male is true

#practice on another
df[df["Team"]=="Finance"]

# more elegant way.is assign to a variable
condition= df["Team"]=="Client Services"
df[condition]

# extract rows wherre senior management is true 
# as long as the series is boolean u can diretly pass it ifo the dataframe
df[df["Senior Management"]]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2019-10-15 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2019-10-15 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2019-10-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2019-10-15 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2019-10-15 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2019-10-15 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2019-10-15 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2019-10-15 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2019-10-15 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2019-10-15 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
df["Team"]!= "Marketing" # returns false for marketing
df[df["Team"]!= "Marketing"]

df[df["Salary"]>11000]
df[df["Bonus %"]<1.5]
# < or > also works with dates
df[df["Start Date"]<= '1985-01-01']
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12 2019-10-15 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2019-10-15 01:08:00  112807   17.492
# 18       Diana  Female 1981-10-23 2019-10-15 10:27:00  132940   19.082
# 28       Terry    Male 1981-11-27 2019-10-15 18:30:00  124008   13.464
# 37       Linda  Female 1981-10-19 2019-10-15 20:49:00   57427    9.557
# ..         ...     ...        ...                 ...     ...      ...
# 982       Rose  Female 1982-04-06 2019-10-15 10:43:00   91411    8.639
# 983       John    Male 1982-12-23 2019-10-15 22:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10 2019-10-15 20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2019-10-15 07:04:00   82871   17.999
# 996    Phillip    Male 1984-01-31 2019-10-15 06:30:00   42392   19.675
#
#      Senior Management             Team
# 10                True              NaN
# ...

# %%
# conditional operators
m1=df["Gender"]== "Male" 
m2=df["Team"]=="Marketing"
df[m1 & m2]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2019-10-15 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2019-10-15 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2019-10-15 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2019-10-15 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2019-10-15 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2019-10-15 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2019-10-15 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2019-10-15 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2019-10-15 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2019-10-15 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2019-10-15 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2019-10-15 09:45:00   55281    4.935
# ...

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-10-15 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-10-15 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-10-15 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2019-10-15 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2019-10-15 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
m1= df["Senior Management"]
m2 = df["Start Date"]< '1990-01-01'
df[m1 | m2] #OR Condition
df.shape
# Out:
# (1000, 8)

# %%
m1 = df["First Name"]=="Robert"
m2 = df["Team"]== "CLient Services"
m3 = df["Start Date"]> '2016-06-01'
df[(m1 & m2 )| m3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2019-10-15 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2019-10-15 19:47:00  100705   16.961
# 451      Terry     NaN 2016-07-15 2019-10-15 00:29:00  140002   19.490
#
#      Senior Management       Team
# 15               False    Product
# 98                True  Marketing
# 451               True  Marketing

# %%
df["Team"].isin(["Legal","Sales","Product"])
#more adaptable for adding and removing features
# also better while comparing
# can also compare two series with isin()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997     True
# 998    False
# 999     True
# Name: Team, Length: 1000, dtype: bool

# %% [markdown]
# ## isnull() notnull()

# %%
df = pd.read_csv("pandas/employees.csv",parse_dates =["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"]= df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-10-15 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-10-15 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-10-15 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df["Team"].isnull() #returns true where null and false when it is not null
m1= df["Team"].isnull()
df[m1]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2019-10-15 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2019-10-15 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2019-10-15 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2019-10-15 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2019-10-15 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2019-10-15 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2019-10-15 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2019-10-15 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2019-10-15 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2019-10-15 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2019-10-15 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2019-10-15 06:06:00   66067   10.957
# ...

# %%
m2 = df["Gender"].notnull()
df[m2]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2019-10-15 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2019-10-15 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2019-10-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2019-10-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2019-10-15 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2019-10-15 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2019-10-15 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2019-10-15 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2019-10-15 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2019-10-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
# between method
# pulling out employees whose salaries are between a specific range
df["Salary"].between(60000,70000) # the bounds are inclusiv4e
df[df["Salary"].between(60000,70000)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2019-10-15 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2019-10-15 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2019-10-15 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2019-10-15 19:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 2019-10-15 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 2019-10-15 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 2019-10-15 20:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 2019-10-15 18:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 2019-10-15 14:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 2019-10-15 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# ...

# %%
df[df["Bonus %"].between(2.0,5.0)]
# also works with dates and times
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2019-10-15 06:53:00   61933    4.170
# 20        Lois     NaN 1995-04-22 2019-10-15 19:18:00   64714    4.934
# 40     Michael    Male 2008-10-10 2019-10-15 11:25:00   99283    2.665
# 49       Chris     NaN 1980-01-24 2019-10-15 12:13:00  113590    3.055
# 60       Paula     NaN 2005-11-23 2019-10-15 14:01:00   48866    4.271
# ..         ...     ...        ...                 ...     ...      ...
# 943      Wayne    Male 2006-09-08 2019-10-15 11:09:00   67471    2.728
# 961    Antonio     NaN 1989-06-18 2019-10-15 21:37:00  103050    3.050
# 976     Denise  Female 1992-10-19 2019-10-15 05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10 2019-10-15 16:58:00   38344    3.794
# 994     George    Male 2013-06-21 2019-10-15 17:47:00   98874    4.479
#
#      Senior Management          Team
# 1                 True           NaN
# 20                True         Legal
# ...

# %%
df[df["Start Date"].between("1991-01-01","1992-01-01")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11 2019-10-15 18:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02 2019-10-15 01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27 2019-10-15 13:59:00   64088    6.155
# 116        NaN    Male 1991-06-22 2019-10-15 20:58:00   76189   18.988
# 148    Patrick     NaN 1991-07-14 2019-10-15 02:24:00  124488   14.837
# 166        NaN  Female 1991-07-09 2019-10-15 18:52:00   42341    7.014
# 172       Sara  Female 1991-09-23 2019-10-15 18:17:00   97058    9.402
# 220        NaN  Female 1991-06-17 2019-10-15 12:49:00   71945    5.560
# 245     Victor    Male 1991-04-11 2019-10-15 07:44:00   70817   17.138
# 277     Brenda     NaN 1991-05-29 2019-10-15 06:32:00   82439   19.062
# 313       Judy  Female 1991-07-01 2019-10-15 02:33:00  109510   13.457
# 328     Samuel    Male 1991-12-19 2019-10-15 02:54:00   76076    5.319
# ...

# %%
# DROP DUPLICATES
# removes where cells accross all the rows are identical (without using arguments)
len(df)
# Out:
# 1000

# %%
df.drop_duplicates(subset=["First Name","Team"])
df.iloc[100:]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 100    Melissa  Female 2005-06-21 2019-10-15 06:33:00   48109   14.995
# 101      Aaron    Male 2012-02-17 2019-10-15 10:20:00   61602   11.849
# 102       Jack    Male 1997-01-12 2019-10-15 05:51:00  103902   12.159
# 103    Phyllis  Female 1996-10-11 2019-10-15 21:30:00  136984    8.932
# 104       John    Male 1989-12-23 2019-10-15 07:01:00   80740   19.305
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2019-10-15 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2019-10-15 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2019-10-15 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2019-10-15 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2019-10-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 100              False               Finance
# ...

# %%
# unique and n unique methods
df["Gender"].unique()
df["Team"].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
#NUNIQUE GIVES THE COUNT IF UNIQUE VALUES
#nunique does not incklude null values

# %% [markdown]
# ### DATAFRAME -III

# %%
import pandas as pd
df= pd.read_csv("pandas/jamesbond.csv") # import film as index index_col= ""
df.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
# set index argument
df.set_index("Film",inplace =True) # to make it permanent add inplace = true
df.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
# reset index...moves the current index to df and generates a brand new inec
df.reset_index(inplace =True)
#df.reset_inex(drop = True,inplace=True) this removes film column totally
# if we again set another column as index it removes previous one
# so first reset and then replace by another column
df.set_index('Year',inplace =True)
df.head(3)
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2

# %% [markdown]
# ## HOW TO RETRIEVE ROWS FROM DF WITH INDEX .loc[ ]

# %%
#sorting an index using sort)_index
df= pd.read_csv("pandas/jamesbond.csv",index_col="Film")
df.sort_index(inplace =True)
df.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
#df.loc to extract rows
df.loc["Goldfinger"]
# returns series

df.loc["GoldenEye"]

#if it haves indecx that has duplicates.It returns a dataframe
df.loc["Casino Royale"]

# extract between two films
df.loc["Diamonds Are Forever": "Moonraker"]
df.loc[:"Goldenfinger"]

# nonsequential movies by passing a list
#use liost of lists
df.loc[['Moonraker','Octopussy']]

# can retrun in any order returns in a specific order
df.loc[['Moonraker','Octopussy','boondi']]

# even if boondi doesnt exist it doesnt give error
# do
"boondi" in df.index
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:19: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
# False

# %%
#iloc extract by index position
#index location( number)
# here final index position is not includes
df= pd.read_csv("pandas/jamesbond.csv")
df.iloc[[15,20]]
df.iloc[15:].head(5)
# Out:
#                     Film  Year           Actor            Director  \
# 15      A View to a Kill  1985     Roger Moore           John Glen
# 16  The Living Daylights  1987  Timothy Dalton           John Glen
# 17       Licence to Kill  1989  Timothy Dalton           John Glen
# 18             GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19   Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
#
#     Box Office  Budget  Bond Actor Salary
# 15       275.2    54.5                9.1
# 16       313.5    68.8                5.2
# 17       250.9    56.7                7.9
# 18       518.5    76.9                5.1
# 19       463.2   133.9               10.0

# %%
df= pd.read_csv("pandas/jamesbond.csv",index_col="Film")
df.sort_index(inplace = True)
df.head(3)
df.iloc[15]
df.iloc[:8] #extract till index 8 , 8 not included
df.iloc[[1,14,16]]
# Out:
#                    Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale      2006  Daniel Craig  Martin Campbell       581.5   145.3
# Octopussy          1983   Roger Moore        John Glen       373.8    53.9
# Quantum of Solace  2008  Daniel Craig     Marc Forster       514.2   181.4
#
#                    Bond Actor Salary
# Film
# Casino Royale                    3.3
# Octopussy                        7.8
# Quantum of Solace                8.1

# %% [markdown]
# ## The Catch-All .ix[ ] method

# %%
df= pd.read_csv("pandas/jamesbond.csv",index_col="Film")
df.sort_index(inplace = True)
df.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
# includes fucntionalities of both loc and iloc
df.ix["GoldenEye"]
df.ix[13]
df.ix["A VIew to a Kill": "The World Is Not Enough"]
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# ...

# %%
# the secon darguments that we can pqass to the loc ,iloc and ix
# second column indicates the column name
df.loc["Moonraker","Director":"Budget"]
df.iloc[13,2:6]
df.ix["Moonraker",1]
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:961: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   return getattr(section, self.name)[new_key]
# 'Roger Moore'

# %%
# Set a new value to a specific cell or row
df.loc["Dr. No","Actor"]="Mrianli"
df.loc["Dr. No","Actor"]
df.loc["Dr. No",["Box Office","Budget"]]=[10,20]
df.loc["Dr. No"]
# Out:
# Year                          1962
# Actor                      Mrianli
# Director             Terence Young
# Box Office                      10
# Budget                          20
# Bond Actor Salary              0.6
# Name: Dr. No, dtype: object

# %%
df.head(10)
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# A View to a Kill       1985     Roger Moore        John Glen       275.2
# Casino Royale          2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale          1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962         Mrianli    Terence Young        10.0
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
#
#                        Budget  Bond Actor Salary
# Film
# A View to a Kill         54.5                9.1
# Casino Royale           145.3                3.3
# ...

# %%
# to replace a specific value in the data frame and replicate that into all the columns
mask = df["Actor"]== "Sean Connery"
df.loc[df["Actor"] == "Sir S Connery"].shape
# Out:
# (0, 6)

# %% [markdown]
# ## Rename indedx Labels or Columns in Data Frame

# %%
df= pd.read_csv("pandas/jamesbond.csv",index_col="Film")
df.sort_index(inplace = True)
df.head(3)
#shift+tab
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
# key represents exixting column name and value represents the value with which we want to replace

df.rename(columns={"Year": "Rel Date","Actor":"Hero"},inplace = True) # changing column names
#changing column names
df.rename(index={"Dr. No":"Doctor No"},inplace = True)
df.head(4)
# Out:
#                       Rel Date          Hero         Director  Box Office  \
# Film
# A View to a Kill          1985   Roger Moore        John Glen       275.2
# Casino Royale             2006  Daniel Craig  Martin Campbell       581.5
# Casino Royale             1967   David Niven       Ken Hughes       315.0
# Diamonds Are Forever      1971  Sean Connery     Guy Hamilton       442.5
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8

# %%
# use df.columns to automatically update
df.columns =['Date','Actor Hero','Director',"Box O",'BUd','BAC']
df.head()
# Out:
#                       Date      Actor Hero         Director  Box O    BUd  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen  275.2   54.5
# Casino Royale         2006    Daniel Craig  Martin Campbell  581.5  145.3
# Casino Royale         1967     David Niven       Ken Hughes  315.0   85.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton  442.5   34.7
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori  465.4  154.2
#
#                        BAC
# Film
# A View to a Kill       9.1
# Casino Royale          3.3
# Casino Royale          NaN
# Diamonds Are Forever   5.8
# Die Another Day       17.9

# %%
# Delete rows and columns from dataframe
df.drop("A View to a Kill")
# to drop multiple values pass list 
df.drop(['Casino Royale','Diamonds Are Forever'])
# to removbe inplace use inplace =True
# axis= 0 represents rows
#axis =1 represenst columns
df.drop(["Box O",'BUd'],axis=1)
# Out:
#                                  Date      Actor Hero            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Doctor No                        1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
# df.pop()is an inplace method and it removes a specific column and returns a dataframe
#example
#df.pop("Actor Hero")
df.head(5)
# we can now assign this series to a variable
# example
#date = df.pop('Date')
# can also use del keyword 
#del df["Director"]
df.head(3)
# all these are inplace
# Out:
#                   Box O    BUd  BAC
# Film
# A View to a Kill  275.2   54.5  9.1
# Casino Royale     581.5  145.3  3.3
# Casino Royale     315.0   85.0  NaN

# %% [markdown]
# ## Create a random sample

# %%
df= pd.read_csv("pandas/jamesbond.csv",index_col="Film")
df.sort_index(inplace = True)
df.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
df.sample()
#defaukltr will return back qa single row
df.sample(n=2) # shift+tab
# sample returns a brand new df
df.sample(n=2,axis =1) # returns two random columns
# can also do axis = colums /'/ both are similar /'/
# Out:
#                                  Year  Bond Actor Salary
# Film
# A View to a Kill                 1985                9.1
# Casino Royale                    2006                3.3
# Casino Royale                    1967                NaN
# Diamonds Are Forever             1971                5.8
# Die Another Day                  2002               17.9
# Dr. No                           1962                0.6
# For Your Eyes Only               1981                NaN
# From Russia with Love            1963                1.6
# GoldenEye                        1995                5.1
# Goldfinger                       1964                3.2
# Licence to Kill                  1989                7.9
# Live and Let Die                 1973                NaN
# Moonraker                        1979                NaN
# Never Say Never Again            1983                NaN
# Octopussy                        1983                7.8
# ...

# %% [markdown]
# ##  .nsmallest() and .nlargest() Methods

# %%
#extract the rows that have the smallest or the largest value in a specific column

df= pd.read_csv("pandas/jamesbond.csv",index_col="Film")
df.sort_index(inplace = True)
df.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
# extract three movies that have highest box offcie
#one way
df.sort_values("Box Office",ascending = False).head(3)
df.nlargest(3,"Box Office") # efficient than sorting
df.nsmallest(2,"Box Office")
# Out:
#                   Year           Actor   Director  Box Office  Budget  \
# Film
# Licence to Kill   1989  Timothy Dalton  John Glen       250.9    56.7
# A View to a Kill  1985     Roger Moore  John Glen       275.2    54.5
#
#                   Bond Actor Salary
# Film
# Licence to Kill                 7.9
# A View to a Kill                9.1

# %%
df.nlargest(4,"Budget",keep='first')
# we can also call n largest directly on a series
df["Box Office"].nlargest(3)
df["Year"].nsmallest(5)
# Out:
# Film
# Dr. No                   1962
# From Russia with Love    1963
# Goldfinger               1964
# Thunderball              1965
# Casino Royale            1967
# Name: Year, dtype: int64

# %% [markdown]
# ## filtering with where method

# %%
# for example we want to extract rows wher evalue in actor colum == something
# normal method
m=df["Actor"]=='Sean Connery'
df[m]
df.where(m)
# this returns the whole data frame but the values are [resent where the actor is only Sean Connery]
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# ...

# %%
df[df["Box Office"]>800]
df.where(df["Box Office"]>800)
# we can also feed multiple columnss int where clause
m2=df["Box Office"]>800
df.where(m & m2)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %% [markdown]
# ## The .query(.) Method
# the argument must only be a string and this method works only when the column name doesnt have space

# %%
df.head()
# hence we re replceing spaces with underscore
cols=[column.replace(" ",'_') for column in df.columns]
cols
df.columns=cols
df.head()
# Out:
#                       Year           Actor         Director  Box_Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond_Actor_Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
df.query('Actor=="Sean Connery"')
# it tends to be faster as per the pandas doc
df.query('Year == 2006')
df.dtypes
# Out:
# Year                   int64
# Actor                 object
# Director              object
# Box_Office           float64
# Budget               float64
# Bond_Actor_Salary    float64
# dtype: object

# %%
df.query("Box_Office>600")
df.query("Actor=='Rodger Moore' or Director=='John Glen'")
# Out:
#                       Year           Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill      1985     Roger Moore  John Glen       275.2    54.5
# For Your Eyes Only    1981     Roger Moore  John Glen       449.4    60.2
# Licence to Kill       1989  Timothy Dalton  John Glen       250.9    56.7
# Octopussy             1983     Roger Moore  John Glen       373.8    53.9
# The Living Daylights  1987  Timothy Dalton  John Glen       313.5    68.8
#
#                       Bond_Actor_Salary
# Film
# A View to a Kill                    9.1
# For Your Eyes Only                  NaN
# Licence to Kill                     7.9
# Octopussy                           7.8
# The Living Daylights                5.2

# %%
df.query("Actor in ['Timothy Dalton','George Lazenby']")
df.query("Actor not in ['Timothy Dalton','George Lazenby']")
# Out:
#                              Year           Actor            Director  \
# Film
# A View to a Kill             1985     Roger Moore           John Glen
# Casino Royale                2006    Daniel Craig     Martin Campbell
# Casino Royale                1967     David Niven          Ken Hughes
# Diamonds Are Forever         1971    Sean Connery        Guy Hamilton
# Die Another Day              2002  Pierce Brosnan        Lee Tamahori
# Dr. No                       1962    Sean Connery       Terence Young
# For Your Eyes Only           1981     Roger Moore           John Glen
# From Russia with Love        1963    Sean Connery       Terence Young
# GoldenEye                    1995  Pierce Brosnan     Martin Campbell
# Goldfinger                   1964    Sean Connery        Guy Hamilton
# Live and Let Die             1973     Roger Moore        Guy Hamilton
# Moonraker                    1979     Roger Moore       Lewis Gilbert
# ...

# %% [markdown]
# ## .apply() method on single columns

# %%
#similar to brodcasting
#defining a function
# takes a funciton and applies it to every value in a series
def convtostring_addmillions(number):
    return str(number)+' MILLIONS'
df["Box_Office"].apply(convtostring_addmillions)
# IF WE WANT TO OVERRITE THEN DO
# df = df["Box_Office"].apply(convtostring_addmillions)

columns=["Box_Office","Budget"]
for column in columns:
    df[column]=df[column].apply(convtostring_addmillions)
df.head(2)
# Out:
#                   Year         Actor         Director  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen
# Casino Royale     2006  Daniel Craig  Martin Campbell
#
#                                        Box_Office  \
# Film
# A View to a Kill  275.2MILLIONSMILLIONS |MILLIONS
# Casino Royale     581.5MILLIONSMILLIONS |MILLIONS
#
#                                            Budget  Bond_Actor_Salary
# Film
# A View to a Kill   54.5MILLIONSMILLIONS |MILLIONS                9.1
# Casino Royale     145.3MILLIONSMILLIONS |MILLIONS                3.3

# %% [markdown]
# ## apply() method with a row values

# %%
df= pd.read_csv("pandas/jamesbond.csv",index_col="Film")
df.sort_index(inplace = True)
df.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def good_movie(row):
   # print(row)
    actor = row[1]
    budget=row[4]
    if actor == 'Pierce Brosnan':
        return "The Best"
    elif actor == 'Rodger Moore' and budget >40:
        return "enjoyable"
    else:
        return "No clue"
df.apply(good_movie,axis=1)
# Out:
# Film
# A View to a Kill                    No clue
# Casino Royale                       No clue
# Casino Royale                       No clue
# Diamonds Are Forever                No clue
# Die Another Day                    The Best
# Dr. No                              No clue
# For Your Eyes Only                  No clue
# From Russia with Love               No clue
# GoldenEye                          The Best
# Goldfinger                          No clue
# Licence to Kill                     No clue
# Live and Let Die                    No clue
# Moonraker                           No clue
# Never Say Never Again               No clue
# Octopussy                           No clue
# On Her Majesty's Secret Service     No clue
# Quantum of Solace                   No clue
# Skyfall                             No clue
# Spectre                             No clue
# The Living Daylights                No clue
# The Man with the Golden Gun         No clue
# ...

# %% [markdown]
# ## Copy method .copy()

# %%
df= pd.read_csv("pandas/jamesbond.csv",index_col="Film")
df.sort_index(inplace = True)
df.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
direct = df["Director"]
direct.head(4)
direct["A View to a Kill"] = "Mister J G"
direct.head()
df.head()
# the df values are Also getting changed
# so to not make any efect on the original dataframe
# we create a copy
# the manipulations on copy does not affect the orioginal operation
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore       Mister J G       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# ...

# %%
direc=df["Director"].copy()
direc["A View to a Kill"] = 'MIs J G'
direc.head(4)
df.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %% [markdown]
# ## working with text data

# %%
import pandas as pd
df= pd.read_csv("pandas/chicago.csv").dropna(how ="all")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null object
# Department                32062 non-null object
# Employee Annual Salary    32062 non-null object
# dtypes: object(4)
# memory usage: 1.2+ MB

# %%
df["Department"].nunique()
# Out:
# 35

# %%
df["Department"].count()
# Out:
# 32062

# %%
df["Department"]=df["Department"].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null object
# Department                32062 non-null category
# Employee Annual Salary    32062 non-null object
# dtypes: category(1), object(3)
# memory usage: 1.0+ MB

# %%
"Hello World".lower() # conv to lower
"hello world".title()
# Out:
# 'Hello World'

# %%
df["Name"]=df["Name"].str.lower()
df.head()
df["Position Title"].str.title()
df["Position Title"].str.len() #gives number of characters which every string has
# Out:
# 0        16
# 1        14
# 2        14
# 3        24
# 4        17
#          ..
# 32057    30
# 32058    14
# 32059    14
# 32060    14
# 32061    23
# Name: Position Title, Length: 32062, dtype: int64

# %%
#.str.replace()
#general
"Hello World".replace("l","k")
df.tail(3)
# Out:
#                       Name           Position Title Department  \
# 32059    zymantas,  mark e           POLICE OFFICER     POLICE
# 32060  zyrkowski,  carlo e           POLICE OFFICER     POLICE
# 32061  zyskowski,  dariusz  CHIEF DATA BASE ANALYST       DoIT
#
#       Employee Annual Salary
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
df["Department"].str.replace("MGMNT","Management")#
df["Department"]=df["Department"].str.replace("MGMNT","Management")
#to replcae inplace

# %%
df["Employee Annual Salary"].str.replace("$","").astype(float)
df["Employee Annual Salary"]=df["Employee Annual Salary"].str.replace("$","").astype(float)
df["Employee Annual Salary"].sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-dde306f31a88> in <module>
# ----> 1 df["Employee Annual Salary"].str.replace("$","").astype(float)
#       2 df["Employee Annual Salary"]=df["Employee Annual Salary"].str.replace("$","").astype(float)
#       3 df["Employee Annual Salary"].sum()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# ...

# %%
df["Employee Annual Salary"].sum()
df["Employee Annual Salary"].mean()
# Out:
# 80204.17863389682

# %%
## FILTERING WITH STRING METHODS

import pandas as pd
df= pd.read_csv("pandas/chicago.csv").dropna(how ="all")
df["Department"]=df["Department"].astype('category')
df.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
# must use .str while method chaining also
mask=df["Position Title"].str.lower().str.contains("water")
df[mask]
# contains looks for that substring sanywhere in the string
# Out:
#                        Name                                 Position Title  \
# 0           AARON,  ELVIA J                               WATER RATE TAKER
# 554      ALUISE,  VINCENT G             FOREMAN OF WATER PIPE CONSTRUCTION
# 671         ANDER,  PERRY A                               WATER CHEMIST II
# 685     ANDERSON,  ANDREW J  DISTRICT SUPERINTENDENT OF WATER DISTRIBUTION
# 702       ANDERSON,  DONALD             FOREMAN OF WATER PIPE CONSTRUCTION
# ...                     ...                                            ...
# 29669        VERMA,  ANUPAM           MANAGING ENGINEER - WATER MANAGEMENT
# 30239   WASHINGTON,  JOSEPH                              WATER CHEMIST III
# 30544       WEST,  THOMAS R                   GEN SUPT OF WATER MANAGEMENT
# 30991    WILLIAMS,  MATTHEW             FOREMAN OF WATER PIPE CONSTRUCTION
# 31405  WOODRIDGE,  ROBERT L             FOREMAN OF WATER PIPE CONSTRUCTION
#
#         Department Employee Annual Salary
# ...

# %%
# to extract the rows that has water in begenning in position title attribute
df[df["Position Title"].str.lower().str.startswith("water")]
#testing for ends with ist
df[df["Position Title"].str.lower().str.endswith("ist")]
# Out:
#                           Name                        Position Title  \
# 184             AFROZ,  NAYYAR                          PSYCHIATRIST
# 308           ALARCON,  LUIS J            LOAN PROCESSING SPECIALIST
# 422           ALLAIN,  CAROLYN  SENIOR TELECOMMUNICATIONS SPECIALIST
# 472             ALLEN,  ROBERT                             MACHINIST
# 705        ANDERSON,  EDWARD M             SR PROCUREMENT SPECIALIST
# ...                        ...                                   ...
# 31667         YODER,  TERESA G                   ARCHIVAL SPECIALIST
# 31688  YOUNGBLOOM,  LAURENCE G        CRIMES SURVEILLANCE SPECIALIST
# 31717       YOUNG,  KIMBERLY M             SR PROCUREMENT SPECIALIST
# 31837            ZAPATA,  HUGO             SR PROCUREMENT SPECIALIST
# 31918        ZEMKE,  RICHARD P                             MACHINIST
#
#                   Department Employee Annual Salary
# 184                   HEALTH              $99840.00
# ...

# %% [markdown]
# ### more string methods -.strip(),.lstrip(),.rstrip()

# %%
# to rem0ve spaces at the beginning or the end
#lstrip - removes form left
#rstrip removes from rigght
# strip general from left or right
"     Hello World".lstrip()
# Out:
# 'Hello World'

# %%
# any string method have to beign ewith .str
df["Name"].str.rstrip().str.lstrip()
# Out:
# 0            AARON,  ELVIA J
# 1          AARON,  JEFFERY M
# 2             AARON,  KARINA
# 3        AARON,  KIMBERLEI R
# 4        ABAD JR,  VICENTE M
#                 ...
# 32057    ZYGADLO,  MICHAEL J
# 32058     ZYGOWICZ,  PETER J
# 32059      ZYMANTAS,  MARK E
# 32060    ZYRKOWSKI,  CARLO E
# 32061    ZYSKOWSKI,  DARIUSZ
# Name: Name, Length: 32062, dtype: object

# %% [markdown]
# ## using string methods on index and columns of our data frame

# %%
#set index as name

import pandas as pd
df= pd.read_csv("pandas/chicago.csv",index_col="Name").dropna(how ="all")
df["Department"]=df["Department"].astype('category')
df.head(3)
# Out:
#                      Position Title   Department Employee Annual Salary
# Name
# AARON,  ELVIA J    WATER RATE TAKER  WATER MGMNT              $90744.00
# AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# AARON,  KARINA       POLICE OFFICER       POLICE              $84450.00

# %%
df.index
#can call string methods on this
df.index=df.index.str.strip().str.title() #assign to overwrite inplace
df.head(3)
# Out:
#                      Position Title   Department Employee Annual Salary
# Name
# Aaron,  Elvia J    WATER RATE TAKER  WATER MGMNT              $90744.00
# Aaron,  Jeffery M    POLICE OFFICER       POLICE              $84450.00
# Aaron,  Karina       POLICE OFFICER       POLICE              $84450.00

# %%
df.columns=df.columns.str.upper()  #upper method on column labels
df.head(2)
# Out:
#                      POSITION TITLE   DEPARTMENT EMPLOYEE ANNUAL SALARY
# Name
# Aaron,  Elvia J    WATER RATE TAKER  WATER MGMNT              $90744.00
# Aaron,  Jeffery M    POLICE OFFICER       POLICE              $84450.00

# %% [markdown]
# ## SPLIT METHOD

# %%
import pandas as pd
df= pd.read_csv("pandas/chicago.csv").dropna(how ="all")
df["Department"]=df["Department"].astype('category')

# %%
"Hello my name is Minnie".split(" ")
#get expects a numerc integer position
df["Name"].str.split(",").str.get(0).str.title().value_counts()
# Out:
# Williams      293
# Johnson       244
# Smith         241
# Brown         185
# Jones         183
#              ...
# Briede          1
# Lewsley         1
# Germino         1
# Skehan          1
# Zickterman      1
# Name: Name, Length: 13829, dtype: int64

# %%
df["Position Title"].str.split(" ").str.get(0).value_counts()
# can count the max number of people in a position
# Out:
# POLICE              10856
# FIREFIGHTER-EMT      1509
# SERGEANT             1186
# POOL                  918
# FIREFIGHTER           810
#                     ...
# SUPERINTENDENT'S        1
# CURATOR                 1
# CAPS                    1
# PURCHASING              1
# MAYOR                   1
# Name: Position Title, Length: 320, dtype: int64

# %%
df.head()
df["Name"].str.split(",").str.get(1).str.strip().str.split(" ").str.get(0).value_counts()
# Out:
# MICHAEL    1153
# JOHN        899
# JAMES       676
# ROBERT      622
# JOSEPH      537
#            ...
# ANTWON        1
# NAILAH        1
# HAMZEH        1
# ALYCE         1
# LUSIA         1
# Name: Name, Length: 5091, dtype: int64

# %%
df["Name"].str.split(",",expand=True)
# we get a dataframe where the list values are separated as columns
df[["firstname","lastname"]]=df["Name"].str.split(",",expand=True)
df.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary  \
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00
#
#   firstname     lastname
# 0     AARON      ELVIA J
# 1     AARON    JEFFERY M
# 2     AARON       KARINA

# %% [markdown]
# ### Creating an multi index

# %%
import pandas as pd
df=pd.read_csv("pandas/bigmac.csv",parse_dates=["Date"])
df.head()
df.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 3 columns):
# Date                   652 non-null datetime64[ns]
# Country                652 non-null object
# Price in US Dollars    652 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 15.4+ KB

# %%
#df.set_index(keys="Country")
# iunless we us ethe inplace parameter e=verything is fine
#now in the keys we use a list to set multiple indexes
#df.set_index(keys=["Date","Country"],inplace=True)

df.head()
df.sort_index(inplace=True)
df.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
df.index.names #return the multi index
df.index
type(df.index)
df.index[0] #returs a tuple of two indexes
# Out:
# (Timestamp('2010-01-01 00:00:00'), 'Argentina')

# %% [markdown]
# # GROUP BY

# %%
df=pd.read_csv("pandas/fortune1000.csv",index_col="Rank")
df.head()
#the idea of group by is to create segments of the data frame
#sector is a perfect one to group by 
#we can segment by sector
sectors=df.groupby("Sector") # u can give a single column or a list of columns
sectors.head(3)
# df.shape
# Out:
#                        Company                        Sector  \
# Rank
# 1                      Walmart                     Retailing
# 2                  Exxon Mobil                        Energy
# 3                        Apple                    Technology
# 4           Berkshire Hathaway                    Financials
# 5                     McKesson                   Health Care
# ...                        ...                           ...
# 195     Marriott International  Hotels, Resturants & Leisure
# 199                    Aramark             Business Services
# 231                         VF                       Apparel
# 235   Jacobs Engineering Group    Engineering & Construction
# 340                        PVH                       Apparel
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %%
#groupby is i=unimpoprtant until we call some methods on it
len(sectors) # we get the number of groupings or setors
len(df) # returns number of rows for dataframe
sectors.size()
df["Sector"].value_counts() # sorted
# index represents the sectors and numbe rof rows that fall under that setor
# Out:
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Food, Beverages & Tobacco        43
# Materials                        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Media                            25
# Hotels, Resturants & Leisure     25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Food and Drug Stores             15
# Telecommunications               15
# Apparel                          15
# Name: Sector, dtype: int64

# %%
#method first( returs the first row from all the different sectors)
sectors.first()
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                           Boeing
# Apparel                                         Nike
# Business Services                      ManpowerGroup
# Chemicals                               Dow Chemical
# Energy                                   Exxon Mobil
# Engineering & Construction                     Fluor
# Financials                        Berkshire Hathaway
# Food and Drug Stores                      CVS Health
# Food, Beverages & Tobacco     Archer Daniels Midland
# Health Care                                 McKesson
# Hotels, Resturants & Leisure              McDonald’s
# Household Products                  Procter & Gamble
# Industrials                         General Electric
# Materials                                      Alcoa
# Media                                         Disney
# Motor Vehicles & Parts                General Motors
# ...
